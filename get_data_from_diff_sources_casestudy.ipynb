# %% [markdown]
# <a href="https://colab.research.google.com/github/rizinahammed/ict_assingments/blob/main/get_data_from_diff_sources_casestudy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 1.Load SpaceX Launch Data from API
# ● Use https://api.spacexdata.com/v4/launches

# %%
import requests
url = "https://api.spacexdata.com/v4/launches"
response=requests.get(url)
data=response.json()
launch_df=pd.DataFrame(data)
launch_df
# Out:
#                                               fairings  \
# 0    {'reused': False, 'recovery_attempt': False, '...
# 1    {'reused': False, 'recovery_attempt': False, '...
# 2    {'reused': False, 'recovery_attempt': False, '...
# 3    {'reused': False, 'recovery_attempt': False, '...
# 4    {'reused': False, 'recovery_attempt': False, '...
# ..                                                 ...
# 200  {'reused': None, 'recovery_attempt': None, 're...
# 201  {'reused': None, 'recovery_attempt': None, 're...
# 202  {'reused': None, 'recovery_attempt': None, 're...
# 203  {'reused': None, 'recovery_attempt': None, 're...
# 204  {'reused': None, 'recovery_attempt': None, 're...
#
#                                                  links  \
# 0    {'patch': {'small': 'https://images2.imgbox.co...
# 1    {'patch': {'small': 'https://images2.imgbox.co...
# 2    {'patch': {'small': 'https://images2.imgbox.co...
# 3    {'patch': {'small': 'https://images2.imgbox.co...
# ...

# %% [markdown]
#  ● Extract relevant columns: name, date_utc, success, details, rocket

# %%
launch_new = launch_df[['name','date_utc','success','details','rocket']]
launch_new
# Out:
#                        name                  date_utc success  \
# 0                 FalconSat  2006-03-24T22:30:00.000Z   False
# 1                   DemoSat  2007-03-21T01:10:00.000Z   False
# 2               Trailblazer  2008-08-03T03:34:00.000Z   False
# 3                    RatSat  2008-09-28T23:15:00.000Z    True
# 4                  RazakSat  2009-07-13T03:35:00.000Z    True
# ..                      ...                       ...     ...
# 200           Transporter-6  2022-12-01T00:00:00.000Z    None
# 201                   TTL-1  2022-12-01T00:00:00.000Z    None
# 202  WorldView Legion 1 & 2  2022-12-01T00:00:00.000Z    None
# 203     Viasat-3 & Arcturus  2022-12-01T00:00:00.000Z    None
# 204          O3b mPower 3.4  2022-12-01T00:00:00.000Z    None
#
#                                                details  \
# 0     Engine failure at 33 seconds and loss of vehicle
# 1    Successful first stage burn and transition to ...
# ...

# %% [markdown]
# ● Convert date_utc to datetime and extract the year

# %%
launch_df['date_utc'] = pd.to_datetime(launch_df['date_utc'])
launch_df['year'] = launch_df['date_utc'].dt.year
launch_df.head()
# Out:
#                                             fairings  \
# 0  {'reused': False, 'recovery_attempt': False, '...
# 1  {'reused': False, 'recovery_attempt': False, '...
# 2  {'reused': False, 'recovery_attempt': False, '...
# 3  {'reused': False, 'recovery_attempt': False, '...
# 4  {'reused': False, 'recovery_attempt': False, '...
#
#                                                links  \
# 0  {'patch': {'small': 'https://images2.imgbox.co...
# 1  {'patch': {'small': 'https://images2.imgbox.co...
# 2  {'patch': {'small': 'https://images2.imgbox.co...
# 3  {'patch': {'small': 'https://images2.imgbox.co...
# 4  {'patch': {'small': 'https://images2.imgbox.co...
#
#        static_fire_date_utc  static_fire_date_unix    net  window  \
# 0  2006-03-17T00:00:00.000Z           1.142554e+09  False     0.0
# 1                      None                    NaN  False     0.0
# 2                      None                    NaN  False     0.0
# ...

# %% [markdown]
# 2.Load Rocket Metadata
# ● Use https://api.spacexdata.com/v4/rockets

# %%
url1='https://api.spacexdata.com/v4/rockets'
response=requests.get(url1)
data2=response.json()
rockets_df=pd.DataFrame(data2)
rockets_df
# Out:
#                           height                        diameter  \
# 0  {'meters': 22.25, 'feet': 73}   {'meters': 1.68, 'feet': 5.5}
# 1  {'meters': 70, 'feet': 229.6}     {'meters': 3.7, 'feet': 12}
# 2  {'meters': 70, 'feet': 229.6}  {'meters': 12.2, 'feet': 39.9}
# 3   {'meters': 118, 'feet': 387}       {'meters': 9, 'feet': 30}
#
#                              mass  \
# 0      {'kg': 30146, 'lb': 66460}
# 1   {'kg': 549054, 'lb': 1207920}
# 2  {'kg': 1420788, 'lb': 3125735}
# 3  {'kg': 1335000, 'lb': 2943000}
#
#                                          first_stage  \
# 0  {'thrust_sea_level': {'kN': 420, 'lbf': 94000}...
# 1  {'thrust_sea_level': {'kN': 7607, 'lbf': 17100...
# 2  {'thrust_sea_level': {'kN': 22819, 'lbf': 5130...
# 3  {'thrust_sea_level': {'kN': 128000, 'lbf': 287...
#
#                                         second_stage  \
# 0  {'thrust': {'kN': 31, 'lbf': 7000}, 'payloads'...
# 1  {'thrust': {'kN': 934, 'lbf': 210000}, 'payloa...
# ...

# %% [markdown]
# ● Extract id, name, type, active, and stages

# %%
rockets_new = rockets_df[['id','type','active','stages']]
rockets_new
# Out:
#                          id    type  active  stages
# 0  5e9d0d95eda69955f709d1eb  rocket   False       2
# 1  5e9d0d95eda69973a809d1ec  rocket    True       2
# 2  5e9d0d95eda69974db09d1ed  rocket    True       2
# 3  5e9d0d96eda699382d09d1ee  rocket   False       2

# %% [markdown]
# 3.Merge Launch and Rocket Data
# ● Join the two DataFrames on rocket ID using

# %%
merged_df = pd.merge(launch_new,rockets_new,left_on='rocket', right_on='id', how='left')

# %%
merged_df
# Out:
#                        name                  date_utc success  \
# 0                 FalconSat  2006-03-24T22:30:00.000Z   False
# 1                   DemoSat  2007-03-21T01:10:00.000Z   False
# 2               Trailblazer  2008-08-03T03:34:00.000Z   False
# 3                    RatSat  2008-09-28T23:15:00.000Z    True
# 4                  RazakSat  2009-07-13T03:35:00.000Z    True
# ..                      ...                       ...     ...
# 200           Transporter-6  2022-12-01T00:00:00.000Z    None
# 201                   TTL-1  2022-12-01T00:00:00.000Z    None
# 202  WorldView Legion 1 & 2  2022-12-01T00:00:00.000Z    None
# 203     Viasat-3 & Arcturus  2022-12-01T00:00:00.000Z    None
# 204          O3b mPower 3.4  2022-12-01T00:00:00.000Z    None
#
#                                                details  \
# 0     Engine failure at 33 seconds and loss of vehicle
# 1    Successful first stage burn and transition to ...
# ...

# %% [markdown]
# Step 4: Add Simulated Country Information
# ● Add a new column country and randomly assign one of these values:
# ['USA', 'Russia', 'India', 'China', 'France']

# %%
countries = ['USA', 'Russia', 'India', 'China', 'France']
merged_df['country_simulated'] = np.random.choice(countries, size=len(merged_df))
merged_df.head()
# Out:
#           name                  date_utc success  \
# 0    FalconSat  2006-03-24T22:30:00.000Z   False
# 1      DemoSat  2007-03-21T01:10:00.000Z   False
# 2  Trailblazer  2008-08-03T03:34:00.000Z   False
# 3       RatSat  2008-09-28T23:15:00.000Z    True
# 4     RazakSat  2009-07-13T03:35:00.000Z    True
#
#                                              details  \
# 0   Engine failure at 33 seconds and loss of vehicle
# 1  Successful first stage burn and transition to ...
# 2  Residual stage 1 thrust led to collision betwe...
# 3  Ratsat was carried to orbit on the first succe...
# 4                                               None
#
#                      rocket                        id    type  active  stages  \
# 0  5e9d0d95eda69955f709d1eb  5e9d0d95eda69955f709d1eb  rocket   False       2
# 1  5e9d0d95eda69955f709d1eb  5e9d0d95eda69955f709d1eb  rocket   False       2
# 2  5e9d0d95eda69955f709d1eb  5e9d0d95eda69955f709d1eb  rocket   False       2
# ...

# %% [markdown]
# Step 5: Store Merged Data in SQLite3
# ● Use sqlite3 to create a connection and save the merged DataFrame as a table named
# launches
# ● Table should contain all merged columns including country

# %%
import sqlite3
conn = sqlite3.connect('spacex.db')
merged_df.to_sql('launches', conn, if_exists='replace', index=False)
# Out:
# 205

# %%
df = pd.read_sql_query("SELECT * FROM launches", conn)
df.head()
# Out:
#           name                  date_utc  success  \
# 0    FalconSat  2006-03-24T22:30:00.000Z      0.0
# 1      DemoSat  2007-03-21T01:10:00.000Z      0.0
# 2  Trailblazer  2008-08-03T03:34:00.000Z      0.0
# 3       RatSat  2008-09-28T23:15:00.000Z      1.0
# 4     RazakSat  2009-07-13T03:35:00.000Z      1.0
#
#                                              details  \
# 0   Engine failure at 33 seconds and loss of vehicle
# 1  Successful first stage burn and transition to ...
# 2  Residual stage 1 thrust led to collision betwe...
# 3  Ratsat was carried to orbit on the first succe...
# 4                                               None
#
#                      rocket                        id    type  active  stages  \
# 0  5e9d0d95eda69955f709d1eb  5e9d0d95eda69955f709d1eb  rocket       0       2
# 1  5e9d0d95eda69955f709d1eb  5e9d0d95eda69955f709d1eb  rocket       0       2
# 2  5e9d0d95eda69955f709d1eb  5e9d0d95eda69955f709d1eb  rocket       0       2
# ...

# %% [markdown]
# Step 6: Run SQL Queries on the Data to analyze
# 1. Launches by Country

# %%
query = """SELECT country_simulated AS country, COUNT(*) AS launch_count FROM launches
GROUP BY country_simulated ORDER BY launch_count DESC;"""

pd.read_sql_query(query, conn)
# Out:
#   country  launch_count
# 0   China            42
# 1     USA            41
# 2  Russia            41
# 3   India            41
# 4  France            40

# %% [markdown]
# 2. Which year had the highest number of launches?

# %%
query= """SELECT strftime('%Y', date_utc) AS year, COUNT(*) AS launch_count FROM launches
GROUP BY year ORDER BY launch_count DESC LIMIT 1;"""

pd.read_sql_query(query, conn)
# Out:
#    year  launch_count
# 0  2022            62

# %% [markdown]
# 3. Top 5 Missions by Launch Count

# %%
query = """SELECT name AS mission_name, COUNT(*) AS launch_count FROM launches
GROUP BY mission_name ORDER BY launch_count DESC LIMIT 5;"""

pd.read_sql_query(query, conn)
# Out:
#                 mission_name  launch_count
# 0  ispace Mission 1 & Rashid             1
# 1                       ZUMA             1
# 2     WorldView Legion 1 & 2             1
# 3        Viasat-3 & Arcturus             1
# 4                    USSF-44             1
